# %%
from pathlib import Path
import pandas as pd
import numpy as np

PROJECT_DIR = Path("/Users/Marcy_Student/Desktop/NBA Project (gh)")

RAW_DIR = PROJECT_DIR / "data" / "raw"
PROCESSED_DIR = PROJECT_DIR / "data" / "processed"

print("RAW exists:", RAW_DIR.exists())
print("PROCESSED exists:", PROCESSED_DIR.exists())

for file in RAW_DIR.glob("*"):
    print(file.name)

# %%
box = pd.read_csv(RAW_DIR / "PlayerStatistics.csv")
advanced = pd.read_csv(RAW_DIR / "PlayerStatisticsAdvanced.csv")
usage = pd.read_csv(RAW_DIR / "PlayerStatisticsUsage.csv")
players = pd.read_csv(RAW_DIR / "Players.csv")
profiles = pd.read_csv(PROCESSED_DIR / "player_profiles_final.csv")

print("box:", box.shape)
print("advanced:", advanced.shape)
print("usage:", usage.shape)
print("players:", players.shape)
print("profiles:", profiles.shape)
